# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:13, 2.39MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
int_words[:10]
# Out:
# [5242, 3082, 11, 5, 194, 1, 3134, 45, 58, 155]

# %%
from collections import Counter

word_counts = Counter(int_words)

# %%
total_words = len(int_words)
keep_words = {}
threshold = 1e-5

for word, count in word_counts.items():
    word_freq = count / total_words
    word_prob = 1 - np.sqrt(threshold/word_freq)
    if np.random.rand() < word_prob:
        keep_words[word] = True

# %%
## Your code here
train_words = [word for word in int_words if word in keep_words]  # The final subsampled word list

# %%
print(total_words, len(train_words))
# Out:
# 16680599 12199945

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r_window = np.random.randint(1, window_size+1)
    start = idx - r_window if (idx - r_window) > 0 else 0
    stop = idx + r_window
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name="inputs")
    labels = tf.placeholder(tf.int32, shape=[None, 1], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  300 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1))  # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal(shape=[n_vocab, n_embedding], stddev=0.1))  # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(shape=[n_vocab]))  # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory 'checkpoints': File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 8.7579 0.0603 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 7.1561 0.0601 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.9190 0.0592 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.1643 0.0588 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 4.8053 0.0590 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 4.5714 0.0588 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 4.3272 0.0587 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 4.2050 0.0588 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.2856 0.0591 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.2586 0.0588 sec/batch
# Nearest to while: from, he, attempted, miles, valuable, shall, speiser, gyms,
# Nearest to years: qaradawi, claim, separate, services, samplers, fundamental, painful, mark,
# Nearest to he: it, cult, made, while, discovered, don, his, lysenko,
# Nearest to time: popularity, number, e, appear, tribe, leading, differentiates, approximately,
# Nearest to only: has, compared, originally, fate, tholos, when, performance, along,
# Nearest to between: work, iii, considerable, o, square, case, plaster, intrigued,
# Nearest to into: live, where, cienfuegos, kda, expertise, born, diocesan, role,
# Nearest to will: auguste, part, scientists, blacklisting, bangor, theory, graveyard, bedded,
# Nearest to orthodox: visit, airport, anniversary, eifel, indicative, look, summer, error,
# Nearest to test: actresses, theory, millions, raeben, complex, queen, clara, allowing,
# Nearest to police: guise, advanced, ultramarine, piece, connects, archbishop, strongest, oliver,
# Nearest to running: kings, liberalised, count, water, u, true, y, edition,
# Nearest to defense: september, them, precarious, large, paleolithic, not, angelos, relatively,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: increasing, after, rivers, libertad, vrml, four, unable, merv,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.2249 0.0599 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.1973 0.0589 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.1269 0.0590 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.1078 0.0587 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.1415 0.0597 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.1461 0.0590 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.1335 0.0590 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.0319 0.0590 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.1374 0.0590 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.0813 0.0589 sec/batch
# Nearest to while: from, he, formats, valuable, crosses, attempted, shall, clothing,
# Nearest to years: qaradawi, painful, separate, jan, claim, samplers, mark, transported,
# Nearest to he: it, cult, made, while, discovered, his, lysenko, don,
# Nearest to time: popularity, number, appear, departures, hhs, differentiates, tribe, leading,
# Nearest to only: fate, has, originally, compared, when, christopher, considered, sung,
# Nearest to between: work, iii, considerable, o, crossing, persons, square, noting,
# Nearest to into: live, where, cienfuegos, kda, expertise, diocesan, interpretation, adherents,
# Nearest to will: auguste, scientists, part, blacklisting, bangor, graveyard, theory, ready,
# Nearest to orthodox: airport, visit, error, anniversary, aimed, look, breaks, eifel,
# Nearest to test: actresses, millions, theory, raeben, acid, clara, ailes, allowing,
# Nearest to police: oliver, guise, piece, strongest, advanced, ultramarine, archbishop, connects,
# Nearest to running: kings, liberalised, y, water, count, u, edition, approach,
# Nearest to defense: tip, kiss, september, graduate, precarious, them, paleolithic, relatively,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: increasing, libertad, beethoven, after, vrml, aegean, merv, rivers,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.0898 0.0602 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.0399 0.0590 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.0346 0.0588 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.0271 0.0591 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.0474 0.0594 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.0311 0.0590 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.0372 0.0590 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.0104 0.0591 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.0283 0.0592 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 3.9613 0.0588 sec/batch
# Nearest to while: from, he, crosses, formats, valuable, attempted, shall, clothing,
# Nearest to years: painful, samplers, qaradawi, separate, transported, jan, services, ekaggata,
# Nearest to he: it, cult, made, while, discovered, his, him, lysenko,
# Nearest to time: popularity, number, appear, departures, tribe, bruins, hhs, differentiates,
# Nearest to only: fate, originally, has, compared, when, considered, along, sung,
# Nearest to between: work, crossing, considerable, iii, case, noting, o, persons,
# Nearest to into: live, kda, cienfuegos, where, diocesan, adherents, expertise, br,
# Nearest to will: auguste, scientists, blacklisting, bangor, part, violence, graveyard, ready,
# Nearest to orthodox: airport, visit, cheops, eifel, error, anniversary, aimed, indicative,
# Nearest to test: actresses, millions, raeben, theory, acid, clara, ailes, relatives,
# Nearest to police: oliver, guise, piece, strongest, advanced, connects, ultramarine, nikita,
# Nearest to running: kings, liberalised, water, y, count, edition, u, about,
# Nearest to defense: tip, kiss, graduate, september, them, precarious, paleolithic, relatively,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: libertad, after, increasing, four, aegean, beethoven, seed, merv,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 3.9961 0.0600 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.0229 0.0591 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 3.9803 0.0611 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 3.9726 0.0600 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 3.9840 0.0595 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 3.9785 0.0592 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 3.9724 0.0589 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 3.9523 0.0589 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 3.9862 0.0591 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 3.9670 0.0591 sec/batch
# Nearest to while: from, crosses, formats, he, valuable, attempted, caesar, temples,
# Nearest to years: painful, separate, qaradawi, ekaggata, samplers, kind, services, jan,
# Nearest to he: it, cult, made, him, while, his, discovered, don,
# Nearest to time: popularity, number, appear, departures, bruins, leading, hhs, differentiates,
# Nearest to only: fate, originally, when, has, compared, considered, sung, plasma,
# Nearest to between: work, o, iii, considerable, case, noting, crossing, legendre,
# Nearest to into: live, where, diocesan, kda, cienfuegos, adherents, areas, decisions,
# Nearest to will: auguste, scientists, blacklisting, bangor, violence, ready, part, animals,
# Nearest to orthodox: airport, eifel, cheops, breaks, aimed, visit, indicative, error,
# Nearest to test: actresses, millions, raeben, theory, acid, clara, ailes, relatives,
# Nearest to police: oliver, guise, piece, strongest, connects, believed, transmuted, nikita,
# Nearest to running: kings, liberalised, water, y, count, playoff, edition, u,
# Nearest to defense: tip, kiss, precarious, graduate, paleolithic, september, them, relatively,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: libertad, increasing, after, seed, aegean, beethoven, merv, four,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 3.9770 0.0607 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 3.9532 0.0593 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 3.9866 0.0595 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 3.9617 0.0614 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 3.9467 0.0591 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 3.9450 0.0589 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 3.8800 0.0586 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 3.9531 0.0589 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 3.9556 0.0591 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 3.9161 0.0588 sec/batch
# Nearest to while: from, crosses, valuable, he, formats, temples, attempted, caesar,
# Nearest to years: painful, ekaggata, samplers, flowing, separate, activision, kind, qaradawi,
# Nearest to he: it, cult, made, him, while, discovered, his, junta,
# Nearest to time: popularity, number, leading, departures, appear, hhs, differentiates, bruins,
# Nearest to only: originally, when, fate, compared, considered, has, more, plasma,
# Nearest to between: work, considerable, o, noting, iii, legendre, case, crossing,
# Nearest to into: live, kda, where, diocesan, cienfuegos, areas, adherents, expertise,
# Nearest to will: auguste, blacklisting, scientists, violence, graveyard, ready, bangor, animals,
# Nearest to orthodox: cheops, eifel, deducted, breaks, anniversary, th, indicative, airport,
# Nearest to test: actresses, theory, raeben, acid, ailes, clara, millions, atari,
# Nearest to police: oliver, guise, piece, strongest, connects, believed, transmuted, ultramarine,
# Nearest to running: kings, liberalised, water, y, count, playoff, edition, circumflex,
# Nearest to defense: tip, kiss, graduate, september, precarious, paleolithic, samples, relatively,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: libertad, after, seed, aegean, four, vrml, increasing, merv,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 3.9576 0.0604 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 3.9664 0.0605 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 3.9407 0.0588 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 3.9691 0.0589 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 3.9188 0.0591 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 3.9662 0.0592 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 3.9683 0.0591 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 3.9081 0.0589 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 3.9310 0.0590 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 3.9645 0.0589 sec/batch
# Nearest to while: from, crosses, he, formats, temples, valuable, brainfuck, attempted,
# Nearest to years: painful, ekaggata, samplers, flowing, activision, kind, drale, separate,
# Nearest to he: it, cult, made, him, while, his, discovered, junta,
# Nearest to time: popularity, hhs, departures, bruins, differentiates, number, appear, leading,
# Nearest to only: originally, fate, when, has, considered, compared, sausages, plasma,
# Nearest to between: legendre, o, work, case, regis, noting, considerable, crossing,
# Nearest to into: live, kda, where, diocesan, cienfuegos, areas, adherents, expertise,
# Nearest to will: auguste, blacklisting, scientists, violence, graveyard, animals, after, ready,
# Nearest to orthodox: cheops, deducted, eifel, indicative, airport, fate, th, novell,
# Nearest to test: actresses, acid, theory, ailes, clara, raeben, millions, ruble,
# Nearest to police: oliver, guise, piece, strongest, connects, ultramarine, believed, transmuted,
# Nearest to running: kings, water, liberalised, y, playoff, circumflex, count, edition,
# Nearest to defense: tip, kiss, precarious, paleolithic, graduate, samples, relatively, september,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: after, aegean, libertad, seed, vrml, mother, merv, increasing,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 3.9277 0.0600 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 3.9256 0.0589 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 3.8784 0.0586 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 3.8991 0.0588 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 3.8559 0.0583 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 3.9828 0.0593 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 3.9285 0.0591 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 3.9379 0.0591 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 3.9054 0.0588 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 3.9176 0.0589 sec/batch
# Nearest to while: from, miles, formats, crosses, brainfuck, temples, valuable, caesar,
# Nearest to years: painful, ekaggata, activision, samplers, next, drale, flowing, spent,
# Nearest to he: cult, it, him, made, junta, while, terran, lysenko,
# Nearest to time: hhs, popularity, bruins, departures, number, differentiates, minute, appear,
# Nearest to only: when, originally, considered, fate, has, compared, sausages, in,
# Nearest to between: regis, o, legendre, considerable, case, noting, intrigued, crossing,
# Nearest to into: live, where, kda, cienfuegos, diocesan, adherents, areas, basse,
# Nearest to will: auguste, blacklisting, scientists, graveyard, violence, animals, making, ready,
# Nearest to orthodox: cheops, deducted, th, indicative, eifel, anniversary, novell, fate,
# Nearest to test: actresses, ailes, acid, raeben, clara, theory, recites, ruble,
# Nearest to police: oliver, piece, guise, strongest, believed, transmuted, ultramarine, nikita,
# Nearest to running: kings, liberalised, water, playoff, circumflex, y, edition, approach,
# Nearest to defense: tip, precarious, paleolithic, kiss, graduate, strongest, september, them,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: libertad, mother, after, vrml, merv, seed, aegean, sarabande,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 3.9218 0.0601 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 3.9191 0.0591 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 3.9120 0.0591 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 3.9193 0.0591 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 3.8967 0.0605 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 3.8910 0.0598 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 3.9137 0.0591 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 3.9085 0.0589 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 3.9152 0.0589 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 3.9049 0.0590 sec/batch
# Nearest to while: from, miles, valuable, brainfuck, formats, crosses, temples, he,
# Nearest to years: painful, ekaggata, flowing, activision, next, qaradawi, drale, samplers,
# Nearest to he: it, cult, him, made, while, junta, terran, lysenko,
# Nearest to time: hhs, bruins, popularity, number, departures, differentiates, minute, appear,
# Nearest to only: originally, fate, when, considered, has, compared, in, essentially,
# Nearest to between: regis, o, legendre, case, deceased, brendan, blessed, iii,
# Nearest to into: live, kda, where, cienfuegos, diocesan, areas, adherents, basse,
# Nearest to will: auguste, blacklisting, animals, scientists, making, graveyard, tell, violence,
# Nearest to orthodox: cheops, deducted, eifel, indicative, fate, th, novell, statutes,
# Nearest to test: actresses, acid, ailes, clara, theory, raeben, ruble, recites,
# Nearest to police: oliver, piece, guise, transmuted, strongest, ankles, ultramarine, believed,
# Nearest to running: liberalised, kings, playoff, water, circumflex, y, approach, count,
# Nearest to defense: tip, precarious, paleolithic, kiss, graduate, strongest, september, booths,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: mother, after, libertad, vrml, sarabande, aegean, mathematician, four,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 3.9222 0.0602 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 3.9063 0.0597 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 3.9188 0.0595 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 3.9303 0.0591 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 3.8740 0.0588 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 3.9214 0.0593 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 3.9243 0.0590 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 3.8653 0.0587 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 3.8861 0.0591 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 3.8919 0.0589 sec/batch
# Nearest to while: from, miles, valuable, brainfuck, crosses, temples, residence, recollection,
# Nearest to years: ekaggata, painful, flowing, activision, qaradawi, spent, drale, samplers,
# Nearest to he: it, cult, him, made, terran, junta, while, lysenko,
# Nearest to time: hhs, popularity, bruins, number, departures, differentiates, minute, diphthong,
# Nearest to only: originally, when, fate, considered, has, compared, essentially, in,
# Nearest to between: regis, legendre, o, brendan, blessed, deceased, galego, considerable,
# Nearest to into: live, kda, where, cienfuegos, diocesan, basse, within, adherents,
# Nearest to will: auguste, blacklisting, animals, tell, making, graveyard, ready, after,
# Nearest to orthodox: cheops, deducted, eifel, indicative, fate, th, novell, statutes,
# Nearest to test: acid, actresses, ailes, clara, raeben, recites, ruble, theory,
# Nearest to police: oliver, guise, transmuted, piece, ankles, connects, ultramarine, nikita,
# Nearest to running: playoff, liberalised, water, circumflex, kings, y, approach, u,
# Nearest to defense: tip, precarious, paleolithic, kiss, booths, graduate, them, strongest,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: mother, after, libertad, aegean, vrml, sarabande, merv, seed,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 3.9140 0.0601 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 3.5667 0.0578 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 3.6774 0.0584 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 3.7682 0.0586 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 3.7841 0.0589 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 3.8972 0.0610 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 3.8580 0.0590 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 3.8993 0.0589 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 3.9159 0.0603 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 3.8916 0.0603 sec/batch
# Nearest to while: from, miles, brainfuck, valuable, residence, temples, attempted, jupiter,
# Nearest to years: ekaggata, spent, painful, flowing, activision, months, drale, qaradawi,
# Nearest to he: it, cult, made, terran, junta, him, its, while,
# Nearest to time: hhs, popularity, bruins, minute, departures, differentiates, number, appear,
# Nearest to only: originally, when, considered, fate, sur, in, compared, has,
# Nearest to between: regis, legendre, brendan, o, intrigued, blessed, iii, deceased,
# Nearest to into: live, kda, cienfuegos, diocesan, where, basse, within, adherents,
# Nearest to will: auguste, blacklisting, animals, tell, after, graveyard, matches, violence,
# Nearest to orthodox: cheops, deducted, eifel, th, indicative, novell, ilmarinen, traditional,
# Nearest to test: ailes, acid, recites, actresses, clara, ruble, raeben, atari,
# Nearest to police: oliver, transmuted, ankles, guise, piece, connects, ultramarine, strongest,
# Nearest to running: playoff, circumflex, liberalised, kings, water, y, shows, approach,
# Nearest to defense: precarious, tip, paleolithic, booths, kiss, war, graduate, them,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: mother, libertad, after, aegean, merv, sarabande, vrml, beethoven,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 3.8831 0.0603 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 3.9112 0.0591 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 3.8653 0.0589 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 3.8759 0.0590 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 3.9160 0.0589 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 3.8556 0.0586 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 3.8994 0.0588 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 3.9002 0.0591 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 3.9046 0.0589 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 3.9092 0.0600 sec/batch
# Nearest to while: from, brainfuck, miles, formats, valuable, jupiter, residence, temples,
# Nearest to years: ekaggata, flowing, months, spent, painful, qaradawi, next, moussa,
# Nearest to he: it, cult, him, made, terran, junta, lysenko, thing,
# Nearest to time: hhs, bruins, minute, popularity, differentiates, departures, number, mahindra,
# Nearest to only: originally, when, fate, considered, essentially, in, compared, sur,
# Nearest to between: regis, legendre, o, intrigued, brendan, galego, deceased, iii,
# Nearest to into: live, kda, cienfuegos, diocesan, where, within, basse, marca,
# Nearest to will: auguste, blacklisting, animals, matches, making, after, ready, tell,
# Nearest to orthodox: cheops, deducted, th, eifel, indicative, novell, fate, ilmarinen,
# Nearest to test: acid, ailes, recites, clara, ruble, actresses, raeben, atari,
# Nearest to police: oliver, ankles, piece, guise, transmuted, ultramarine, strongest, connects,
# Nearest to running: playoff, liberalised, circumflex, water, approach, y, theme, shows,
# Nearest to defense: precarious, booths, paleolithic, tip, kiss, force, bureau, war,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: mother, libertad, aegean, after, merv, vrml, sarabande, seed,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 3.8339 0.0598 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 3.8060 0.0588 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 3.8624 0.0587 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 3.8423 0.0590 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 3.8087 0.0589 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 3.8691 0.0592 sec/batch
# Epoch 1/10 Iteration: 11700 Avg. Training loss: 3.9062 0.0592 sec/batch
# Epoch 1/10 Iteration: 11800 Avg. Training loss: 3.8385 0.0593 sec/batch
# Epoch 1/10 Iteration: 11900 Avg. Training loss: 3.8081 0.0590 sec/batch
# Epoch 1/10 Iteration: 12000 Avg. Training loss: 3.8832 0.0594 sec/batch
# Nearest to while: from, brainfuck, miles, formats, nevertheless, residence, jupiter, valuable,
# Nearest to years: months, spent, ekaggata, flowing, painful, next, qaradawi, activision,
# Nearest to he: cult, it, him, made, terran, junta, movimiento, lysenko,
# Nearest to time: hhs, minute, bruins, differentiates, popularity, number, departures, appear,
# Nearest to only: originally, when, fate, considered, sur, essentially, in, rumi,
# Nearest to between: regis, legendre, brendan, intrigued, galego, deceased, into, crossing,
# Nearest to into: live, basse, cienfuegos, kda, within, diocesan, where, marca,
# Nearest to will: auguste, blacklisting, matches, animals, graveyard, continues, after, ready,
# Nearest to orthodox: th, deducted, cheops, protestant, eifel, roman, novell, indicative,
# Nearest to test: acid, ailes, recites, clara, actresses, raeben, ruble, atari,
# Nearest to police: oliver, ankles, piece, transmuted, guise, notepad, ultramarine, connects,
# Nearest to running: playoff, liberalised, circumflex, water, theme, minnie, shows, pill,
# Nearest to defense: precarious, booths, paleolithic, force, bureau, tip, strongest, kiss,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: mother, libertad, after, aegean, merv, vrml, sarabande, seed,
# Epoch 1/10 Iteration: 12100 Avg. Training loss: 3.8901 0.0606 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 3.8963 0.0012 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 3.9151 0.0591 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 3.8857 0.0591 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 3.8916 0.0590 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 3.8395 0.0590 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 3.8587 0.0589 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 3.8459 0.0588 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 3.7754 0.0584 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 3.7797 0.0588 sec/batch
# Nearest to while: from, residence, brainfuck, miles, nevertheless, jupiter, speiser, valuable,
# Nearest to years: months, flowing, spent, ekaggata, painful, next, activision, drale,
# Nearest to he: it, cult, him, made, terran, junta, movimiento, thing,
# Nearest to time: hhs, bruins, minute, popularity, differentiates, departures, number, lenition,
# Nearest to only: originally, when, fate, considered, in, essentially, sur, rumi,
# Nearest to between: regis, legendre, brendan, o, iii, into, plaster, intrigued,
# Nearest to into: live, within, cienfuegos, kda, diocesan, autonomous, basse, where,
# Nearest to will: auguste, blacklisting, matches, graveyard, animals, ready, continues, after,
# Nearest to orthodox: deducted, th, cheops, novell, eifel, roman, observances, principally,
# Nearest to test: ailes, acid, recites, actresses, clara, raeben, ruble, atari,
# Nearest to police: oliver, ankles, piece, transmuted, guise, notepad, connects, believed,
# Nearest to running: playoff, circumflex, water, liberalised, theme, shows, pill, away,
# Nearest to defense: precarious, booths, paleolithic, force, tip, bureau, destroy, them,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: mother, after, libertad, aegean, merv, sarabande, vrml, four,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 3.8407 0.0599 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 3.8808 0.0594 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 3.8489 0.0591 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 3.8532 0.0588 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 3.8579 0.0590 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 3.8387 0.0591 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 3.8981 0.0592 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 3.8879 0.0592 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 3.8983 0.0591 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 3.8025 0.0586 sec/batch
# Nearest to while: from, miles, residence, brainfuck, praising, jupiter, speiser, valuable,
# Nearest to years: months, ekaggata, painful, spent, next, flowing, activision, drale,
# Nearest to he: it, cult, him, terran, junta, made, movimiento, civilian,
# Nearest to time: hhs, minute, bruins, popularity, differentiates, departures, number, mahindra,
# Nearest to only: originally, when, fate, considered, sur, in, rumi, suspiciously,
# Nearest to between: legendre, regis, intrigued, into, o, crossing, brendan, blessed,
# Nearest to into: live, within, cienfuegos, autonomous, kda, basse, diocesan, marca,
# Nearest to will: auguste, blacklisting, matches, animals, ready, continues, graveyard, after,
# Nearest to orthodox: deducted, cheops, th, roman, novell, eifel, indicative, protestant,
# Nearest to test: ailes, recites, acid, ruble, clara, actresses, raeben, atari,
# Nearest to police: oliver, ankles, transmuted, guise, notepad, connects, piece, nikita,
# Nearest to running: playoff, circumflex, liberalised, water, shows, eruptive, theme, pill,
# Nearest to defense: precarious, force, booths, paleolithic, bureau, tip, destroy, september,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, symbol, steric,
# Nearest to brother: mother, merv, libertad, after, beethoven, sarabande, vrml, aegean,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 3.9107 0.0600 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 3.8671 0.0590 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 3.9159 0.0591 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 3.8937 0.0592 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 3.8693 0.0590 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 3.8531 0.0587 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 3.8898 0.0595 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 3.8719 0.0592 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 3.8725 0.0589 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 3.8751 0.0591 sec/batch
# Nearest to while: from, miles, residence, brainfuck, jupiter, praising, speiser, insubordination,
# Nearest to years: months, ekaggata, flowing, documented, painful, spent, next, qaradawi,
# Nearest to he: it, cult, him, terran, junta, made, movimiento, civilian,
# Nearest to time: hhs, bruins, minute, differentiates, popularity, departures, number, mahindra,
# Nearest to only: originally, fate, when, sur, considered, in, rumi, essentially,
# Nearest to between: regis, legendre, intrigued, into, brendan, blessed, galego, crossed,
# Nearest to into: within, live, kda, cienfuegos, autonomous, diocesan, marca, basse,
# Nearest to will: auguste, blacklisting, matches, animals, graveyard, amerigo, ready, continues,
# Nearest to orthodox: deducted, cheops, roman, th, novell, protestant, eifel, indicative,
# Nearest to test: ailes, acid, recites, ruble, actresses, clara, atari, raeben,
# Nearest to police: oliver, ankles, transmuted, notepad, guise, connects, piece, nikita,
# Nearest to running: playoff, circumflex, water, liberalised, away, shows, eruptive, pill,
# Nearest to defense: precarious, force, booths, paleolithic, bureau, destroy, tip, strongest,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, symbol, steric,
# Nearest to brother: mother, merv, libertad, beethoven, aegean, after, sarabande, four,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 3.8882 0.0601 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 3.8101 0.0601 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 3.8605 0.0599 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 3.8989 0.0590 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 3.8742 0.0589 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 3.8713 0.0589 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 3.8739 0.0592 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 3.8952 0.0593 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 3.8356 0.0586 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 3.8780 0.0590 sec/batch
# Nearest to while: from, miles, brainfuck, jupiter, residence, nevertheless, speiser, insubordination,
# Nearest to years: months, ekaggata, flowing, spent, painful, documented, next, qaradawi,
# Nearest to he: it, cult, him, terran, junta, made, movimiento, piety,
# Nearest to time: hhs, bruins, minute, differentiates, departures, popularity, medicaid, number,
# Nearest to only: originally, fate, when, sur, considered, rumi, in, essentially,
# Nearest to between: regis, intrigued, legendre, brendan, galego, o, into, ricin,
# Nearest to into: within, cienfuegos, live, kda, diocesan, marca, basse, autonomous,
# Nearest to will: auguste, blacklisting, graveyard, ready, matches, continues, amerigo, animals,
# Nearest to orthodox: deducted, cheops, roman, novell, th, indicative, eifel, protestant,
# Nearest to test: ailes, acid, recites, ruble, clara, actresses, atari, raeben,
# Nearest to police: oliver, ankles, transmuted, guise, notepad, connects, venda, piece,
# Nearest to running: playoff, circumflex, liberalised, water, eruptive, shows, away, minnie,
# Nearest to defense: precarious, force, booths, paleolithic, bureau, destroy, september, strongest,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, symbol, steric,
# Nearest to brother: mother, merv, libertad, after, aegean, beethoven, sarabande, vrml,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 3.8788 0.0601 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 3.8590 0.0593 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 3.8696 0.0592 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 3.8706 0.0593 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 3.8885 0.0591 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 3.8826 0.0590 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 3.8357 0.0592 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 3.8536 0.0589 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 3.8009 0.0595 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 3.8753 0.0593 sec/batch
# Nearest to while: from, miles, brainfuck, residence, nevertheless, jupiter, insubordination, connick,
# Nearest to years: months, ekaggata, flowing, painful, spent, documented, qaradawi, decades,
# Nearest to he: it, cult, him, terran, junta, pontifex, piety, movimiento,
# Nearest to time: hhs, bruins, minute, differentiates, popularity, departures, medicaid, number,
# Nearest to only: originally, when, fate, considered, sur, in, rumi, essentially,
# Nearest to between: regis, intrigued, brendan, galego, legendre, o, into, blessed,
# Nearest to into: within, live, kda, cienfuegos, marca, diocesan, basse, constantly,
# Nearest to will: auguste, blacklisting, matches, graveyard, ready, continues, amerigo, compounded,
# Nearest to orthodox: deducted, cheops, roman, th, novell, eifel, indicative, observances,
# Nearest to test: ailes, ruble, acid, recites, clara, actresses, atari, raeben,
# Nearest to police: oliver, transmuted, ankles, guise, notepad, connects, nikita, venda,
# Nearest to running: playoff, circumflex, liberalised, shows, water, eruptive, away, minnie,
# Nearest to defense: precarious, force, booths, paleolithic, september, bureau, destroy, coleoptera,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, symbol, steric,
# Nearest to brother: mother, merv, libertad, sarabande, beethoven, after, aegean, vrml,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 3.8637 0.0599 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 3.8607 0.0590 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 3.8733 0.0591 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 3.8844 0.0591 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 3.8484 0.0591 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 3.8986 0.0617 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 3.8498 0.0593 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 3.8742 0.0594 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 3.8767 0.0597 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 3.8451 0.0589 sec/batch
# Nearest to while: from, miles, brainfuck, residence, nevertheless, insubordination, jupiter, connick,
# Nearest to years: months, ekaggata, spent, decades, documented, flowing, painful, next,
# Nearest to he: it, cult, him, terran, junta, pontifex, civilian, movimiento,
# Nearest to time: hhs, bruins, minute, differentiates, popularity, departures, medicaid, rambling,
# Nearest to only: originally, fate, sur, considered, when, rumi, in, suspiciously,
# Nearest to between: regis, intrigued, into, brendan, legendre, baladan, galego, plaster,
# Nearest to into: within, live, cienfuegos, kda, marca, autonomous, between, basse,
# Nearest to will: auguste, blacklisting, graveyard, matches, continues, amerigo, ready, overlordship,
# Nearest to orthodox: deducted, cheops, novell, roman, indicative, th, eifel, methodical,
# Nearest to test: ailes, acid, recites, ruble, clara, atari, theory, actresses,
# Nearest to police: oliver, transmuted, ankles, notepad, guise, connects, nikita, animate,
# Nearest to running: playoff, circumflex, liberalised, shows, water, implements, theme, eruptive,
# Nearest to defense: force, precarious, booths, paleolithic, september, bureau, destroy, strongest,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, symbol, steric,
# Nearest to brother: mother, merv, sarabande, libertad, after, aegean, vrml, beethoven,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 3.8497 0.0601 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 3.8767 0.0588 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 3.8692 0.0589 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 3.9075 0.0590 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 3.8176 0.0586 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 3.8417 0.0588 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 3.7829 0.0584 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 3.8901 0.0592 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 3.8665 0.0589 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 3.8897 0.0591 sec/batch
# Nearest to while: from, miles, brainfuck, insubordination, nevertheless, jupiter, connick, formats,
# Nearest to years: months, decades, ekaggata, spent, documented, flowing, painful, qaradawi,
# Nearest to he: it, cult, him, terran, junta, civilian, pontifex, movimiento,
# Nearest to time: hhs, minute, bruins, departures, differentiates, popularity, medicaid, mahindra,
# Nearest to only: originally, fate, sur, when, considered, rumi, suspiciously, in,
# Nearest to between: regis, brendan, intrigued, legendre, galego, baladan, blessed, into,
# Nearest to into: within, live, kda, cienfuegos, marca, autonomous, basse, nationalrat,
# Nearest to will: auguste, blacklisting, graveyard, matches, continues, amerigo, ready, compounded,
# Nearest to orthodox: deducted, cheops, th, roman, novell, observances, nostra, indicative,
# Nearest to test: ailes, recites, acid, ruble, clara, beckwith, actresses, theory,
# Nearest to police: oliver, transmuted, ankles, notepad, guise, connects, feverish, animate,
# Nearest to running: playoff, circumflex, liberalised, shows, mael, away, water, implements,
# Nearest to defense: force, precarious, booths, september, paleolithic, bureau, strongest, turboexpress,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: mother, merv, libertad, sarabande, aegean, vrml, after, geological,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 3.8357 0.0600 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 3.8590 0.0590 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 3.8506 0.0591 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 3.8613 0.0590 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 3.8689 0.0591 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 3.8667 0.0589 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 3.8791 0.0595 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 3.8691 0.0591 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 3.8866 0.0594 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 3.8828 0.0588 sec/batch
# Nearest to while: from, miles, brainfuck, insubordination, nevertheless, connick, jupiter, residence,
# Nearest to years: months, decades, spent, ekaggata, documented, flowing, painful, thirty,
# Nearest to he: it, cult, terran, him, civilian, junta, pontifex, schell,
# Nearest to time: hhs, bruins, minute, popularity, differentiates, departures, medicaid, rambling,
# Nearest to only: originally, fate, sur, when, considered, rumi, in, suspiciously,
# Nearest to between: regis, brendan, intrigued, baladan, legendre, into, plaster, blessed,
# Nearest to into: within, live, cienfuegos, kda, diocesan, basse, marca, nationalrat,
# Nearest to will: auguste, blacklisting, matches, graveyard, continues, amerigo, ready, overlordship,
# Nearest to orthodox: deducted, cheops, th, roman, novell, eifel, nostra, indicative,
# Nearest to test: ailes, recites, acid, ruble, clara, theory, actresses, beckwith,
# Nearest to police: oliver, transmuted, ankles, notepad, connects, guise, animate, venda,
# Nearest to running: playoff, circumflex, shows, liberalised, away, water, mael, minnie,
# Nearest to defense: force, precarious, booths, september, paleolithic, bureau, turboexpress, strongest,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, symbol, steric,
# Nearest to brother: mother, sarabande, merv, libertad, after, aegean, geological, vrml,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 3.8820 0.0601 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 3.8524 0.0588 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 3.8738 0.0594 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 3.8693 0.0595 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 3.8795 0.0597 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 3.8601 0.0590 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 3.8291 0.0589 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 3.9035 0.0589 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 3.8694 0.0593 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 3.8171 0.0586 sec/batch
# Nearest to while: from, brainfuck, miles, insubordination, nevertheless, connick, jupiter, formats,
# Nearest to years: months, decades, spent, flowing, ekaggata, documented, qaradawi, painful,
# Nearest to he: it, cult, terran, him, pontifex, civilian, junta, schell,
# Nearest to time: hhs, bruins, minute, differentiates, departures, popularity, medicaid, rambling,
# Nearest to only: originally, fate, sur, when, considered, rumi, essentially, in,
# Nearest to between: regis, brendan, intrigued, legendre, baladan, blessed, galego, into,
# Nearest to into: within, live, cienfuegos, kda, marca, autonomous, nationalrat, basse,
# Nearest to will: auguste, blacklisting, matches, continues, graveyard, amerigo, ready, could,
# Nearest to orthodox: deducted, cheops, th, indicative, novell, eifel, ilmarinen, roman,
# Nearest to test: recites, ailes, ruble, acid, clara, theory, beckwith, actresses,
# Nearest to police: oliver, transmuted, ankles, notepad, connects, guise, animate, venda,
# Nearest to running: playoff, circumflex, liberalised, shows, implements, minnie, eruptive, mael,
# Nearest to defense: force, precarious, booths, september, paleolithic, bureau, turboexpress, program,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: mother, libertad, sarabande, merv, aegean, vrml, geological, erlang,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 3.8452 0.0607 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 3.8407 0.0592 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 3.8635 0.0589 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 3.5124 0.0576 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 3.6885 0.0582 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 3.6957 0.0583 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 3.7664 0.0586 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 3.8467 0.0597 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 3.8400 0.0600 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 3.8560 0.0588 sec/batch
# Nearest to while: from, insubordination, miles, nevertheless, residence, brainfuck, connick, jupiter,
# Nearest to years: months, decades, ekaggata, spent, painful, documented, flowing, thirty,
# Nearest to he: it, cult, terran, civilian, junta, schell, him, pontifex,
# Nearest to time: hhs, minute, bruins, differentiates, popularity, departures, medicaid, rambling,
# Nearest to only: fate, originally, when, rumi, sur, in, considered, essentially,
# Nearest to between: regis, brendan, intrigued, baladan, legendre, blessed, into, fudge,
# Nearest to into: within, kda, cienfuegos, live, marca, diocesan, basse, nationalrat,
# Nearest to will: auguste, blacklisting, continues, matches, graveyard, ready, amerigo, could,
# Nearest to orthodox: deducted, cheops, th, novell, indicative, eifel, ilmarinen, roman,
# Nearest to test: ailes, recites, ruble, acid, clara, theory, raeben, beckwith,
# Nearest to police: oliver, transmuted, ankles, notepad, connects, guise, animate, venda,
# Nearest to running: playoff, circumflex, liberalised, shows, mael, minnie, eruptive, implements,
# Nearest to defense: precarious, force, booths, september, paleolithic, bureau, turboexpress, coleoptera,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, promoter, aldred, steric, onyx,
# Nearest to brother: mother, libertad, sarabande, merv, after, aegean, seed, beethoven,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 3.8752 0.0606 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 3.8616 0.0593 sec/batch
# Epoch 2/10 Iteration: 22300 Avg. Training loss: 3.8497 0.0591 sec/batch
# Epoch 2/10 Iteration: 22400 Avg. Training loss: 3.8755 0.0592 sec/batch
# Epoch 2/10 Iteration: 22500 Avg. Training loss: 3.8330 0.0590 sec/batch
# Epoch 2/10 Iteration: 22600 Avg. Training loss: 3.8296 0.0588 sec/batch
# Epoch 2/10 Iteration: 22700 Avg. Training loss: 3.8831 0.0590 sec/batch
# Epoch 2/10 Iteration: 22800 Avg. Training loss: 3.8081 0.0585 sec/batch
# Epoch 2/10 Iteration: 22900 Avg. Training loss: 3.8716 0.0587 sec/batch
# Epoch 2/10 Iteration: 23000 Avg. Training loss: 3.8677 0.0589 sec/batch
# Nearest to while: from, miles, brainfuck, nevertheless, insubordination, jupiter, connick, residence,
# Nearest to years: months, decades, flowing, documented, ekaggata, painful, qaradawi, spent,
# Nearest to he: it, cult, terran, him, schell, civilian, junta, receptor,
# Nearest to time: hhs, minute, bruins, departures, differentiates, medicaid, popularity, rambling,
# Nearest to only: originally, fate, rumi, in, sur, when, considered, essentially,
# Nearest to between: regis, intrigued, brendan, legendre, baladan, ricin, galego, blotter,
# ...
# Nearest to defense: precarious, force, booths, september, turboexpress, paleolithic, thrush, angelos,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, symbol, promoter, aldred, steric,
# Nearest to brother: mother, merv, libertad, erlang, sarabande, aegean, subalgebra, garret,
# Epoch 3/10 Iteration: 29100 Avg. Training loss: 3.7888 0.0599 sec/batch
# Epoch 3/10 Iteration: 29200 Avg. Training loss: 3.8637 0.0594 sec/batch
# Epoch 3/10 Iteration: 29300 Avg. Training loss: 3.8386 0.0589 sec/batch
# Epoch 3/10 Iteration: 29400 Avg. Training loss: 3.8436 0.0590 sec/batch
# Epoch 3/10 Iteration: 29500 Avg. Training loss: 3.8703 0.0590 sec/batch
# Epoch 3/10 Iteration: 29600 Avg. Training loss: 3.8513 0.0591 sec/batch
# Epoch 3/10 Iteration: 29700 Avg. Training loss: 3.8204 0.0589 sec/batch
# Epoch 3/10 Iteration: 29800 Avg. Training loss: 3.8692 0.0592 sec/batch
# Epoch 3/10 Iteration: 29900 Avg. Training loss: 3.8195 0.0600 sec/batch
# Epoch 3/10 Iteration: 30000 Avg. Training loss: 3.8702 0.0592 sec/batch
# Nearest to while: from, nevertheless, insubordination, connick, jupiter, brainfuck, miles, speiser,
# Nearest to years: months, decades, centuries, thirty, documented, painful, flowing, ekaggata,
# Nearest to he: it, cult, terran, him, schell, pontifex, receptor, civilian,
# Nearest to time: hhs, minute, bruins, departures, popularity, medicaid, differentiates, tomino,
# Nearest to only: originally, fate, sur, considered, rumi, in, essentially, gesta,
# Nearest to between: regis, brendan, intrigued, ricin, crossing, baladan, blotter, galego,
# Nearest to into: within, kda, cienfuegos, marca, nationalrat, separated, diocesan, live,
# Nearest to will: auguste, blacklisting, continues, graveyard, matches, amerigo, overlordship, screws,
# Nearest to orthodox: roman, deducted, observances, th, cheops, novell, ilmarinen, marries,
# Nearest to test: ailes, recites, ruble, acid, clara, theory, layer, beckwith,
# Nearest to police: oliver, transmuted, ankles, notepad, guise, connects, noise, animate,
# Nearest to running: playoff, circumflex, liberalised, shows, mael, minnie, sill, portions,
# Nearest to defense: force, precarious, booths, september, turboexpress, paleolithic, thrush, bernhardt,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, symbol, promoter, aldred, steric,
# Nearest to brother: mother, merv, aegean, sarabande, libertad, subalgebra, erlang, geological,
# Epoch 3/10 Iteration: 30100 Avg. Training loss: 3.8759 0.0603 sec/batch
# Epoch 3/10 Iteration: 30200 Avg. Training loss: 3.8501 0.0590 sec/batch
# Epoch 3/10 Iteration: 30300 Avg. Training loss: 3.8617 0.0591 sec/batch
# Epoch 3/10 Iteration: 30400 Avg. Training loss: 3.8517 0.0589 sec/batch
# Epoch 3/10 Iteration: 30500 Avg. Training loss: 3.8561 0.0591 sec/batch
# Epoch 3/10 Iteration: 30600 Avg. Training loss: 3.8505 0.0590 sec/batch
# Epoch 3/10 Iteration: 30700 Avg. Training loss: 3.7646 0.0587 sec/batch
# Epoch 3/10 Iteration: 30800 Avg. Training loss: 3.8340 0.0589 sec/batch
# Epoch 3/10 Iteration: 30900 Avg. Training loss: 3.7634 0.0584 sec/batch
# Epoch 3/10 Iteration: 31000 Avg. Training loss: 3.8862 0.0595 sec/batch
# Nearest to while: from, insubordination, nevertheless, connick, brainfuck, jupiter, miles, motoring,
# Nearest to years: months, decades, centuries, thirty, flowing, minutes, painful, thebans,
# Nearest to he: it, terran, cult, schell, receptor, him, pontifex, junta,
# Nearest to time: hhs, minute, bruins, departures, popularity, medicaid, differentiates, tomino,
# Nearest to only: originally, fate, sur, rumi, considered, essentially, suspiciously, gesta,
# Nearest to between: regis, brendan, intrigued, baladan, ricin, crossing, blessed, fudge,
# Nearest to into: within, kda, cienfuegos, marca, diocesan, nationalrat, live, upright,
# Nearest to will: auguste, blacklisting, continues, graveyard, matches, clients, amerigo, overlordship,
# Nearest to orthodox: deducted, roman, novell, cheops, th, indicative, ilmarinen, observances,
# Nearest to test: ailes, recites, ruble, clara, acid, theory, layer, endogenous,
# Nearest to police: oliver, transmuted, ankles, notepad, connects, guise, gotta, venda,
# Nearest to running: playoff, circumflex, shows, mael, liberalised, minnie, lekhanya, runs,
# Nearest to defense: force, precarious, booths, september, turboexpress, thrush, paleolithic, bernhardt,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, symbol, promoter, aldred, steric,
# Nearest to brother: mother, subalgebra, aegean, sarabande, merv, erlang, libertad, geological,
# Epoch 3/10 Iteration: 31100 Avg. Training loss: 3.8672 0.0607 sec/batch
# Epoch 3/10 Iteration: 31200 Avg. Training loss: 3.8671 0.0597 sec/batch
# Epoch 3/10 Iteration: 31300 Avg. Training loss: 3.8166 0.0594 sec/batch
# Epoch 3/10 Iteration: 31400 Avg. Training loss: 3.8430 0.0599 sec/batch
# Epoch 3/10 Iteration: 31500 Avg. Training loss: 3.8353 0.0588 sec/batch
# Epoch 3/10 Iteration: 31600 Avg. Training loss: 3.8632 0.0591 sec/batch
# Epoch 3/10 Iteration: 31700 Avg. Training loss: 3.8514 0.0590 sec/batch
# Epoch 3/10 Iteration: 31800 Avg. Training loss: 3.8630 0.0591 sec/batch
# Epoch 3/10 Iteration: 31900 Avg. Training loss: 3.8446 0.0591 sec/batch
# Epoch 3/10 Iteration: 32000 Avg. Training loss: 3.8220 0.0591 sec/batch
# Nearest to while: from, insubordination, nevertheless, brainfuck, connick, jupiter, miles, notably,
# Nearest to years: months, decades, thirty, painful, minutes, centuries, ekaggata, flowing,
# Nearest to he: it, terran, cult, schell, receptor, pontifex, civilian, moines,
# Nearest to time: hhs, minute, departures, bruins, popularity, medicaid, differentiates, tomino,
# Nearest to only: originally, fate, sur, rumi, essentially, considered, in, suspiciously,
# Nearest to between: brendan, regis, baladan, intrigued, crossing, blessed, fudge, roaring,
# Nearest to into: within, kda, nationalrat, cienfuegos, diocesan, separated, upright, marca,
# Nearest to will: auguste, blacklisting, continues, graveyard, matches, amerigo, overlordship, clients,
# Nearest to orthodox: deducted, roman, novell, th, cheops, ilmarinen, indicative, mci,
# Nearest to test: ailes, recites, ruble, theory, clara, acid, layer, endogenous,
# Nearest to police: oliver, transmuted, guise, notepad, ankles, animate, connects, noise,
# Nearest to running: playoff, shows, mael, circumflex, liberalised, minnie, lekhanya, runs,
# Nearest to defense: force, precarious, booths, september, turboexpress, thrush, paleolithic, bernhardt,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, symbol, promoter, aldred, steric,
# Nearest to brother: mother, erlang, merv, sarabande, subalgebra, aegean, garret, libertad,
# Epoch 3/10 Iteration: 32100 Avg. Training loss: 3.8686 0.0603 sec/batch
# Epoch 3/10 Iteration: 32200 Avg. Training loss: 3.8548 0.0588 sec/batch
# Epoch 3/10 Iteration: 32300 Avg. Training loss: 3.8627 0.0595 sec/batch
# Epoch 3/10 Iteration: 32400 Avg. Training loss: 3.8516 0.0611 sec/batch
# Epoch 3/10 Iteration: 32500 Avg. Training loss: 3.8668 0.0591 sec/batch
# Epoch 3/10 Iteration: 32600 Avg. Training loss: 3.8499 0.0594 sec/batch
# Epoch 3/10 Iteration: 32700 Avg. Training loss: 3.8721 0.0596 sec/batch
# Epoch 3/10 Iteration: 32800 Avg. Training loss: 3.8542 0.0597 sec/batch
# Epoch 3/10 Iteration: 32900 Avg. Training loss: 3.8062 0.0590 sec/batch
# Epoch 3/10 Iteration: 33000 Avg. Training loss: 3.8527 0.0593 sec/batch
# Nearest to while: from, insubordination, nevertheless, brainfuck, connick, jupiter, miles, notably,
# Nearest to years: months, decades, thirty, centuries, painful, minutes, thebans, documented,
# Nearest to he: it, terran, cult, schell, receptor, pontifex, winery, him,
# Nearest to time: hhs, minute, bruins, departures, medicaid, popularity, tomino, differentiates,
# Nearest to only: originally, fate, rumi, sur, essentially, considered, in, gesta,
# Nearest to between: brendan, regis, baladan, blessed, intrigued, roaring, fudge, ricin,
# Nearest to into: within, nationalrat, kda, cienfuegos, separated, marca, diocesan, live,
# Nearest to will: auguste, blacklisting, continues, graveyard, amerigo, matches, overlordship, screws,
# Nearest to orthodox: deducted, cheops, roman, novell, th, indicative, ilmarinen, eifel,
# Nearest to test: ailes, recites, ruble, layer, theory, clara, acid, bolivia,
# Nearest to police: oliver, transmuted, notepad, guise, ankles, connects, animate, venda,
# Nearest to running: playoff, circumflex, shows, liberalised, mael, lekhanya, minnie, true,
# Nearest to defense: force, precarious, booths, september, turboexpress, paleolithic, bernhardt, thrush,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, symbol, promoter, aldred, steric,
# Nearest to brother: mother, sarabande, subalgebra, garret, erlang, aegean, geological, libertad,
# Epoch 3/10 Iteration: 33100 Avg. Training loss: 3.8618 0.0602 sec/batch
# Epoch 3/10 Iteration: 33200 Avg. Training loss: 3.8082 0.0586 sec/batch
# Epoch 3/10 Iteration: 33300 Avg. Training loss: 3.8243 0.0592 sec/batch
# Epoch 3/10 Iteration: 33400 Avg. Training loss: 3.8410 0.0590 sec/batch
# Epoch 3/10 Iteration: 33500 Avg. Training loss: 3.8502 0.0590 sec/batch
# Epoch 3/10 Iteration: 33600 Avg. Training loss: 3.5057 0.0576 sec/batch
# Epoch 3/10 Iteration: 33700 Avg. Training loss: 3.6825 0.0582 sec/batch
# Epoch 3/10 Iteration: 33800 Avg. Training loss: 3.6931 0.0584 sec/batch
# Epoch 3/10 Iteration: 33900 Avg. Training loss: 3.7482 0.0596 sec/batch
# Epoch 3/10 Iteration: 34000 Avg. Training loss: 3.8343 0.0591 sec/batch
# Nearest to while: from, insubordination, nevertheless, connick, brainfuck, residence, jupiter, notably,
# Nearest to years: months, decades, centuries, thirty, painful, minutes, flowing, thebans,
# Nearest to he: it, terran, cult, schell, receptor, moines, monticello, pontifex,
# Nearest to time: hhs, minute, departures, medicaid, bruins, popularity, differentiates, rambling,
# Nearest to only: fate, originally, rumi, sur, in, considered, essentially, suspiciously,
# Nearest to between: brendan, regis, baladan, intrigued, blessed, crossing, roaring, fudge,
# Nearest to into: within, kda, cienfuegos, nationalrat, marca, diocesan, live, through,
# Nearest to will: auguste, blacklisting, continues, graveyard, kanchenjunga, amerigo, s, matches,
# Nearest to orthodox: deducted, th, novell, cheops, ilmarinen, indicative, roman, marries,
# Nearest to test: recites, ailes, ruble, theory, acid, layer, clara, beckwith,
# Nearest to police: oliver, transmuted, notepad, guise, ankles, connects, animate, venda,
# Nearest to running: playoff, shows, circumflex, mael, lekhanya, liberalised, minnie, charitable,
# Nearest to defense: force, precarious, booths, september, turboexpress, thrush, bernhardt, paleolithic,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, symbol, promoter, aldred, steric,
# Nearest to brother: mother, aegean, garret, libertad, erlang, sarabande, merv, four,
# Epoch 3/10 Iteration: 34100 Avg. Training loss: 3.8225 0.0601 sec/batch
# Epoch 3/10 Iteration: 34200 Avg. Training loss: 3.8518 0.0589 sec/batch
# Epoch 3/10 Iteration: 34300 Avg. Training loss: 3.8780 0.0591 sec/batch
# Epoch 3/10 Iteration: 34400 Avg. Training loss: 3.8529 0.0591 sec/batch
# Epoch 3/10 Iteration: 34500 Avg. Training loss: 3.8558 0.0592 sec/batch
# Epoch 3/10 Iteration: 34600 Avg. Training loss: 3.8723 0.0591 sec/batch
# Epoch 3/10 Iteration: 34700 Avg. Training loss: 3.8154 0.0590 sec/batch
# Epoch 3/10 Iteration: 34800 Avg. Training loss: 3.8374 0.0591 sec/batch
# Epoch 3/10 Iteration: 34900 Avg. Training loss: 3.8693 0.0596 sec/batch
# Epoch 3/10 Iteration: 35000 Avg. Training loss: 3.8082 0.0583 sec/batch
# Nearest to while: from, insubordination, nevertheless, brainfuck, connick, jupiter, miles, notably,
# Nearest to years: months, decades, centuries, painful, thirty, minutes, flowing, ekaggata,
# Nearest to he: it, terran, cult, receptor, schell, moines, incheon, monticello,
# Nearest to time: hhs, minute, departures, bruins, medicaid, popularity, differentiates, period,
# Nearest to only: fate, originally, rumi, sur, in, gesta, essentially, considered,
# Nearest to between: brendan, regis, roaring, baladan, intrigued, ricin, crossing, blessed,
# Nearest to into: within, kda, separated, nationalrat, cienfuegos, marca, diocesan, upright,
# Nearest to will: auguste, blacklisting, continues, graveyard, matches, overlordship, tend, kanchenjunga,
# Nearest to orthodox: deducted, th, novell, cheops, indicative, roman, ilmarinen, aruch,
# Nearest to test: recites, ailes, ruble, layer, theory, acid, clara, bend,
# Nearest to police: oliver, notepad, guise, transmuted, animate, noise, ankles, venda,
# Nearest to running: playoff, circumflex, shows, lekhanya, mael, liberalised, true, portions,
# Nearest to defense: precarious, force, booths, september, turboexpress, thrush, bernhardt, paleolithic,
# Nearest to universe: prohibits, gdf, pandemonium, shiga, diem, polity, lyre, heyday,
# Nearest to proposed: ephesians, crespigny, detroit, objectivity, symbol, promoter, aldred, steric,
# Nearest to brother: mother, garret, erlang, aegean, libertad, merv, sarabande, subalgebra,
# Epoch 3/10 Iteration: 35100 Avg. Training loss: 3.8396 0.0598 sec/batch
# Epoch 3/10 Iteration: 35200 Avg. Training loss: 3.8569 0.0589 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-b1d3869cd0d6> in <module>()
#      18             feed = {inputs: x,
#      19                     labels: np.array(y)[:, None]}
# ---> 20             train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
#      21
#      22             loss += train_loss
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
